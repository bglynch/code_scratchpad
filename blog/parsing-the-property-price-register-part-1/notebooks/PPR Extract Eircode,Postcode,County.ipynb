# %%
import os
import pandas as pd
import re
import sqlite3
from hashlib import blake2b
from importlib import reload

# %%
os.chdir('../')

# %%
from src import extract as ex
from src import parse as pr
from src import normalise as nm

# %% [markdown]
# ## Prepare Data

# %%
# load data
df = pd.read_csv("data/raw/PPR-ALL.csv", encoding='latin-1')
# create uuid
df = df.rename(columns={
    'Date of Sale (dd/mm/yyyy)': 'date',
    'Address': 'address',
    'Postal Code': 'postcode',
    'County': 'county',
    'Price (\x80)': 'price',
    'Not Full Market Price': 'not_full_market_price',
    'VAT Exclusive': 'vat_exclusive',
    'Property Size Description': 'floor_area',
    'Description of Property': 'construction',
})

# create uuid for each
for row in df.copy().itertuples():
    # hash_id_string = f"{row.date}{row.address}{row.price}"
    hash_id_string = f"{row.date}{row.address}{row.postcode}{row.county}{row.price}{row.not_full_market_price}{row.vat_exclusive}{row.floor_area}{row.construction}"
    df.at[row.Index, 'uuid'] = blake2b(bytes(hash_id_string, "utf-8"), digest_size=5).hexdigest()

# remove duplicates
df.drop_duplicates(inplace=True)

df.set_index('uuid', inplace=True)
# Out:
# /Users/br20069521/Desktop/Date-Dump/21-03-07/code_scratchpad/blog/parsing-the-property-price-register-part-1/venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
db_url = "data/database.db"
conn = sqlite3.connect(db_url)
cur = conn.cursor()
df.to_sql('ppr_all', conn)
cur.close()
conn.close()

# %% [markdown]
# ### Create tempoary data table

# %%
conn = sqlite3.connect('data/database.db')
df = pd.read_sql_query('SELECT * FROM ppr_all', conn)
df.set_index('uuid', inplace=True)

df = df.drop(["date","price","not_full_market_price","construction","floor_area","vat_exclusive"], axis=1)
df.insert(3, 'ex_eircode', None)
df.insert(3, 'ex_county', None)
df.insert(3, 'ex_postcode', None)
df.insert(3, 'address_mod', None)
df.insert(3, 'xx', None)
df.address_mod = df.address.str.lower()


cur = conn.cursor()
cur.execute(f"DROP TABLE IF EXISTS temp;")
df.to_sql('temp', conn)
cur.close()
conn.close()

# %%
df
# Out:
#                                                    address postcode    county  \
# uuid
# b306a21836          5 Braemor Drive, Churchtown, Co.Dublin     None    Dublin
# 42e8eed8ad  134 Ashewood Walk, Summerhill Lane, Portlaoise     None     Laois
# 7b08b5e03d             1 Meadow Avenue, Dundrum, Dublin 14     None    Dublin
# 2352e180f5                         1 The Haven, Mornington     None     Meath
# cbac7ce7bd                   11 Melville Heights, Kilkenny     None  Kilkenny
# ...                                                    ...      ...       ...
# b39bcc2471                CROSSNEEN, GRAIGUECULLEN, CARLOW     None     Laois
# b65b929588                     GORTADERRA, SCARRIFF, CLARE     None     Clare
# 3e02f239ba                 HALSEYRATH, DUNCORMICK, WEXFORD     None   Wexford
# b99e66ddea             RIVERSIDE, BEHEENAGH, KNOCKNAGOSHEL     None     Kerry
# fe602cd8ea                   SMEAR, AUGHNACLIFFE, LONGFORD     None  Longford
#
#               xx                                     address_mod ex_postcode  \
# uuid
# b306a21836  None          5 braemor drive, churchtown, co.dublin        None
# 42e8eed8ad  None  134 ashewood walk, summerhill lane, portlaoise        None
# 7b08b5e03d  None             1 meadow avenue, dundrum, dublin 14        None
# 2352e180f5  None                         1 the haven, mornington        None
# cbac7ce7bd  None                   11 melville heights, kilkenny        None
# ...          ...                                             ...         ...
# b39bcc2471  None                crossneen, graiguecullen, carlow        None
# b65b929588  None                     gortaderra, scarriff, clare        None
# 3e02f239ba  None                 halseyrath, duncormick, wexford        None
# b99e66ddea  None             riverside, beheenagh, knocknagoshel        None
# fe602cd8ea  None                   smear, aughnacliffe, longford        None
#
#            ex_county ex_eircode
# uuid
# b306a21836      None       None
# 42e8eed8ad      None       None
# 7b08b5e03d      None       None
# 2352e180f5      None       None
# cbac7ce7bd      None       None
# ...              ...        ...
# b39bcc2471      None       None
# b65b929588      None       None
# 3e02f239ba      None       None
# b99e66ddea      None       None
# fe602cd8ea      None       None
#
# [468967 rows x 8 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Eirccode Extraction

# %%
conn = sqlite3.connect('data/database.db')
df = pd.read_sql_query('SELECT * FROM temp;', conn)
df.set_index('uuid', inplace=True)
df
# Out:
#                                                    address postcode    county  \
# uuid
# b306a21836          5 Braemor Drive, Churchtown, Co.Dublin     None    Dublin
# 42e8eed8ad  134 Ashewood Walk, Summerhill Lane, Portlaoise     None     Laois
# 7b08b5e03d             1 Meadow Avenue, Dundrum, Dublin 14     None    Dublin
# 2352e180f5                         1 The Haven, Mornington     None     Meath
# cbac7ce7bd                   11 Melville Heights, Kilkenny     None  Kilkenny
# ...                                                    ...      ...       ...
# b39bcc2471                CROSSNEEN, GRAIGUECULLEN, CARLOW     None     Laois
# b65b929588                     GORTADERRA, SCARRIFF, CLARE     None     Clare
# 3e02f239ba                 HALSEYRATH, DUNCORMICK, WEXFORD     None   Wexford
# b99e66ddea             RIVERSIDE, BEHEENAGH, KNOCKNAGOSHEL     None     Kerry
# fe602cd8ea                   SMEAR, AUGHNACLIFFE, LONGFORD     None  Longford
#
#               xx                                     address_mod ex_postcode  \
# uuid
# b306a21836  None          5 braemor drive, churchtown, co.dublin        None
# 42e8eed8ad  None  134 ashewood walk, summerhill lane, portlaoise        None
# 7b08b5e03d  None             1 meadow avenue, dundrum, dublin 14        None
# 2352e180f5  None                         1 the haven, mornington        None
# cbac7ce7bd  None                   11 melville heights, kilkenny        None
# ...          ...                                             ...         ...
# b39bcc2471  None                crossneen, graiguecullen, carlow        None
# b65b929588  None                     gortaderra, scarriff, clare        None
# 3e02f239ba  None                 halseyrath, duncormick, wexford        None
# b99e66ddea  None             riverside, beheenagh, knocknagoshel        None
# fe602cd8ea  None                   smear, aughnacliffe, longford        None
#
#            ex_county ex_eircode
# uuid
# b306a21836      None       None
# 42e8eed8ad      None       None
# 7b08b5e03d      None       None
# 2352e180f5      None       None
# cbac7ce7bd      None       None
# ...              ...        ...
# b39bcc2471      None       None
# b65b929588      None       None
# 3e02f239ba      None       None
# b99e66ddea      None       None
# fe602cd8ea      None       None
#
# [468967 rows x 8 columns]

# %%
for row in df.copy().itertuples():
    eircode = ex.extract_eircode_from_end_of_address(row.address_mod)
    if eircode is not None:
        df.at[row.Index, 'ex_eircode'] = eircode
        df.at[row.Index, 'address_mod'] = pr.parse_address_of_eircode(row.address_mod)

# %%
cur = conn.cursor()
cur.execute(f"DROP TABLE IF EXISTS temp;")
df.to_sql('temp', conn)
cur.close()
conn.close()

# %% [markdown]
# ## Dublin Postcode Extraction

# %%
conn = sqlite3.connect('data/database.db')
df = pd.read_sql_query('SELECT * FROM temp;', conn)
df.set_index('uuid', inplace=True)
df.address_mod = df.address_mod.apply(nm.normalise_dublin_postcode)

for row in df.copy().itertuples():
    postcode = ex.extract_dublin_postcode_from_address(row.address_mod)
    if postcode is not None:
        df.at[row.Index, 'ex_postcode'] = postcode
        df.at[row.Index, 'address_mod'] = pr.parse_address_of_dublin_postcode(row.address_mod)
        
cur = conn.cursor()
cur.execute(f"DROP TABLE IF EXISTS temp;")
df.to_sql('temp', conn)
cur.close()
conn.close()

# %% [markdown]
# ## County Extraction

# %%
conn = sqlite3.connect('data/database.db')
df = pd.read_sql_query('SELECT * FROM temp;', conn)
df.set_index('uuid', inplace=True)

df.address_mod = df.address_mod.apply(nm.normalise_county)
for row in df.copy().itertuples():
    county = ex.extract_county_from_address(row.address_mod)
    if county is not None:
        df.at[row.Index, 'ex_county'] = county
        df.at[row.Index, 'address_mod'] = pr.parse_address_of_county(row.address_mod)
cur = conn.cursor()
cur.execute(f"DROP TABLE IF EXISTS temp;")
df.to_sql('temp', conn)
cur.close()
conn.close()

# %% [markdown]
# ## Combine with Origional Dataset

# %%
conn = sqlite3.connect('data/database.db')
df_orig = pd.read_sql_query('SELECT * FROM ppr_all;', conn)
conn.close()
df_orig.set_index('uuid', inplace=True)
df_orig.insert(4, 'eircode', None)
df_orig.head()
# Out:
#                   date                                         address  \
# uuid
# b306a21836  01/01/2010          5 Braemor Drive, Churchtown, Co.Dublin
# 42e8eed8ad  03/01/2010  134 Ashewood Walk, Summerhill Lane, Portlaoise
# 7b08b5e03d  04/01/2010             1 Meadow Avenue, Dundrum, Dublin 14
# 2352e180f5  04/01/2010                         1 The Haven, Mornington
# cbac7ce7bd  04/01/2010                   11 Melville Heights, Kilkenny
#
#            postcode    county eircode        price not_full_market_price  \
# uuid
# b306a21836     None    Dublin    None  343,000.00                    No
# 42e8eed8ad     None     Laois    None  185,000.00                    No
# 7b08b5e03d     None    Dublin    None  438,500.00                    No
# 2352e180f5     None     Meath    None  400,000.00                    No
# cbac7ce7bd     None  Kilkenny    None  160,000.00                    No
#
#            vat_exclusive                           construction  \
# uuid
# b306a21836            No  Second-Hand Dwelling house /Apartment
# 42e8eed8ad           Yes          New Dwelling house /Apartment
# 7b08b5e03d            No  Second-Hand Dwelling house /Apartment
# 2352e180f5            No  Second-Hand Dwelling house /Apartment
# cbac7ce7bd            No  Second-Hand Dwelling house /Apartment
#
#                                                    floor_area
# uuid
# b306a21836                                               None
# 42e8eed8ad  greater than or equal to 38 sq metres and less...
# 7b08b5e03d                                               None
# 2352e180f5                                               None
# cbac7ce7bd                                               None

# %% [markdown]
# ### Combine Eircode

# %%
conn = sqlite3.connect('data/database.db')
df = pd.read_sql_query('SELECT * FROM temp WHERE ex_eircode NOT NULL;', conn)
conn.close()
df.set_index('uuid', inplace=True)
df.head()
# Out:
#                                                       address postcode  \
# uuid
# ccf905f559         2 SLANELOUGH, ASHFORD, CO WICKLOW A67 ED73     None
# f649ac5a17  PARSONS GATES, BELMONT R0AD, CASTLECONNELL V94...     None
# be0c8afe5b            7 Montpellier Terrace, Galway, H91 C2DN     None
# 3abb465dd9      21 Harbour View, The Square, Clifden H71 AH59     None
# bbad706bf6  Apartment 19 Desart Court, New Street, Kilkenn...     None
#
#               county  xx                                 address_mod  \
# uuid
# ccf905f559   Wicklow  xx                       2 slanelough, ashford
# f649ac5a17  Limerick  xx  parsons gates, belmont r0ad, castleconnell
# be0c8afe5b    Galway  xx                       7 montpellier terrace
# 3abb465dd9    Galway  xx        21 harbour view, the square, clifden
# bbad706bf6  Kilkenny  xx       apartment 19 desart court, new street
#
#            ex_postcode ex_county ex_eircode
# uuid
# ccf905f559        None   Wicklow   A67 ED73
# f649ac5a17        None      None   V94 VPW3
# be0c8afe5b        None    Galway   H91 C2DN
# 3abb465dd9        None      None   H71 AH59
# bbad706bf6        None  Kilkenny   R95 X050

# %%
for row in df.copy().itertuples():
    df_orig.at[row.Index, 'address'] = row.address_mod.title()
    df_orig.at[row.Index, 'eircode'] = row.ex_eircode

# %% [markdown]
# ### Combine Dublin Postcode

# %%
conn = sqlite3.connect('data/database.db')
df = pd.read_sql_query('SELECT * FROM temp WHERE ex_postcode NOT NULL;', conn)
conn.close()
df.set_index('uuid', inplace=True)
df.head()
# Out:
#                                               address postcode  county    xx  \
# uuid
# 7b08b5e03d        1 Meadow Avenue, Dundrum, Dublin 14     None  Dublin  None
# 6b35e03f73  206 Philipsburgh Avenue, Marino, Dublin 3     None  Dublin  None
# a7cf1b1d16     22 Laverna Way, Castleknock, Dublin 15     None  Dublin  None
# dc92e8c267      33 RAGIAN ROAD, BALLSBRIDGE, DUBLIN 4     None  Dublin  None
# 6d10ff8567          5 Clancy Road, Finglas, Dublin 11     None  Dublin  None
#
#                                 address_mod ex_postcode ex_county ex_eircode
# uuid
# 7b08b5e03d         1 meadow avenue, dundrum   Dublin 14      None       None
# 6b35e03f73  206 philipsburgh avenue, marino    Dublin 3      None       None
# a7cf1b1d16      22 laverna way, castleknock   Dublin 15      None       None
# dc92e8c267      33 ragian road, ballsbridge    Dublin 4      None       None
# 6d10ff8567           5 clancy road, finglas   Dublin 11      None       None

# %%
for row in df.copy().itertuples():
    ex_postcode = row.ex_postcode
    postcode = row.postcode
    county = row.county
    if postcode is None:
        df_orig.at[row.Index, 'postcode'] = row.ex_postcode
        if county != 'Dublin':
            df_orig.at[row.Index, 'county'] = f"{county}, (ex_postcode: Dublin)"
    else:
        if postcode.title() != ex_postcode:
            df_orig.at[row.Index, 'postcode'] = f"{postcode}, (ex_postcode: {ex_postcode})"
        if county != 'Dublin':
            df_orig.at[row.Index, 'county'] = f"{county}, (ex_postcode: Dublin)"
    df_orig.at[row.Index, 'address'] = row.address_mod.title()

# %% [markdown]
# ### Combine County

# %%
conn = sqlite3.connect('data/database.db')
df = pd.read_sql_query('SELECT * FROM temp WHERE ex_county NOT NULL;', conn)
conn.close()
df.set_index('uuid', inplace=True)
df.head()
# Out:
#                                                   address postcode    county  \
# uuid
# b306a21836         5 Braemor Drive, Churchtown, Co.Dublin     None    Dublin
# cbac7ce7bd                  11 Melville Heights, Kilkenny     None  Kilkenny
# 42679e4628        13  Oakleigh Wood, Dooradoyle, Limerick     None  Limerick
# decc394ad1          25  Lavallin Drive, Whitechurch, Cork     None      Cork
# 347e854a9b  44 Allen Park Road, Stillorgan, County Dublin     None    Dublin
#
#               xx                      address_mod ex_postcode ex_county  \
# uuid
# b306a21836  None      5 braemor drive, churchtown        None    Dublin
# cbac7ce7bd  None              11 melville heights        None  Kilkenny
# 42679e4628  None    13  oakleigh wood, dooradoyle        None  Limerick
# decc394ad1  None  25  lavallin drive, whitechurch        None      Cork
# 347e854a9b  None   44 allen park road, stillorgan        None    Dublin
#
#            ex_eircode
# uuid
# b306a21836       None
# cbac7ce7bd       None
# 42679e4628       None
# decc394ad1       None
# 347e854a9b       None

# %%
for row in df.copy().itertuples():
    ex_county = row.ex_county
    county = row.county
    if county != ex_county:
        df_orig.at[row.Index, 'county'] = f"{county}, (ex_county: {ex_county})"
    df_orig.at[row.Index, 'address'] = row.address_mod.title()

# %%
conn = sqlite3.connect('data/database.db')
cur = conn.cursor()
cur.execute(f"DROP TABLE IF EXISTS ppr_all_mod;")
df_orig.to_sql('ppr_all_mod', conn)
cur.close()
conn.close()
